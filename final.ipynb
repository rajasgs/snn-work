# %%
import pandas as pd

# %%
df = pd.read_csv('abc.csv')

# %%
df.sample(2)
# Out:
#      address_name_LEFT            address_1_LEFT  address_2_LEFT  \
# 1268      LISA,JACKSON        0008 ROBERT VALLEY             NaN
# 532       SEAN,WATKINS  368 DAVIS ISLE SUITE 886             NaN
#
#          city_LEFT     state_LEFT  ZIP_LEFT Country_LEFT address_name_RIGHT  \
# 1268  NEW JOHNPORT  MASSACHUSETTS   76467.0          USA       LISA,JACKSON
# 532   REBECCAMOUTH        GEORGIA    5512.0          USA       SEAN,WATKINS
#
#                address_1_RIGHT address_2_RIGHT    city_RIGHT    state_RIGHT  \
# 1268        0008 ROBERT VALLEY             NaN  NEW JOHNPORT  MASSACHUSETTS
# 532   368 DAVIS ISLE SUITE 886             NaN  REBECCAMOUTH        GEORGIA
#
#       ZIP_RIGHT Country Result
# 1268    76467.0     USA  MATCH
# 532      5512.0     USA  MATCH

# %%
df.rename(columns={'address_1_LEFT': 'address_LEFT', 'address_1_RIGHT': 'address_RIGHT'}, inplace=True)

# %%
df = df.drop(['address_2_LEFT', 'address_2_RIGHT'], axis=1)

# %%
df
# Out:
#           address_name_LEFT                    address_LEFT        city_LEFT  \
# 0            HOERNER,AUDREY               462 GRIDER STREET          BUFFALO
# 1              BITRAN,JOYCE          1441 CONSTITUTION BLVD          SALINAS
# 2            HOERNER,AUDREY               462 GRIDER STREET          BUFFALO
# 3     MASK CUSTOMER - 33604                             NaN            TAMPA
# 4           MARQUEZ MENDOZA                   777 E 25TH ST          HIALEAH
# ...                     ...                             ...              ...
# 2051         KEVIN,GONZALEZ        985 PITTS SPURS APT. 845  EAST DAKOTALAND
# 2052               SCOTT,LE                  459 ERICA KEYS     LAKE JESSICA
# 2053         DAVID,HAMILTON  357 RONNIE EXTENSIONS APT. 688       WANDASHIRE
# 2054            ERIC,SUAREZ               025 DANIEL SUMMIT        EMILYTOWN
# 2055         TIFFANY,LOWERY                75103 CODY FORKS      WEST SANDRA
#
# ...

# %%
df.to_csv(
    'abc2.csv',
    index = False
)
